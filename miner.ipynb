# %% [markdown]
# <a href="https://colab.research.google.com/github/azisrw69/diyaa/blob/main/miner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BOT 5 IN 1 (NANOPOOL)**
# 1.   Cek GPU NVIDIA
# 2.   Update Repo Ethereum
# 3.   Cek IP Public
# 4.   Cek CPU
# 5.   Eksekusi Mining ETH Pool NANOPOOL

# %%
# !nvidia-smi

# %%
# !sudo add-apt-repository ppa:ethereum/ethereum
# !sudo cat /etc/apt/sources.list
# !sudo apt update
# !sudo apt install ethereum

# %%
# !curl ipinfo.io

# %%
# !lscpu

# %%
# !git clone https://github.com/azisrw69/diyaa.git
# %cd diyaa
# !chmod +x ./nanominer
# !./nanominer
